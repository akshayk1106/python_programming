# %% [markdown]
# #### <mark> Pandas correlation
# A great aspect of the Pandas module is the corr() method.
#
# The corr() method calculates the relationship between each column in your data set.
#
# The corr() method ignores "not numeric" columns.

# %%
import pandas as pd
data = pd.read_csv('diabetes.csv')
df = pd.DataFrame(data)
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [raw]
# The number varies from -1 to 1.
#
# 1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.
#
# 0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.
#
# -0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.
#
# 0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

# %% [markdown]
# #### <mark> Dummy variables
#
#     pandas.get_dummies(
#         data,
#         prefix=None,
#         prefix_sep='_',
#         dummy_na=False,
#         columns=None,
#         sparse=False,
#         drop_first=False,
#         dtype=None
#         )

# %%
df1 = pd.DataFrame({'id': ['paul', 'rocky', 'lea'], 
                   'gender': ['M', 'M', 'F'],
                   'age': [1, 2, 3]
                  })

pd.get_dummies(df1, 
               columns=['id'], 
               drop_first=True, 
               prefix=['dummy'], 
               prefix_sep='---')
# Out:
#   gender  age  dummy---paul  dummy---rocky
# 0      M    1             1              0
# 1      M    2             0              1
# 2      F    3             0              0

# %% [markdown]
# #### <mark> Binning

# %% [markdown]
# ### <mark> Pandas uses the plot() method to create diagrams.
#
# We can use Pyplot, a submodule of the Matplotlib library to visualize the diagram on the screen.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df.plot()
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Age', y = 'BMI')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BMI'>

# %%
df.plot(kind = 'scatter', x = 'BMI', y = 'BloodPressure')
# Out:
# <AxesSubplot:xlabel='BMI', ylabel='BloodPressure'>

# %%
df["Insulin"].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
